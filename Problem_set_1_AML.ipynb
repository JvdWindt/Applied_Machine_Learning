# %% [markdown]
# <a href="https://colab.research.google.com/github/JvdWindt/Applied_Machine_Learning/blob/main/Problem_set_1_AML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Applied Machine Learning')

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Applied Machine Learning/train_data.csv")
print(data.shape)
data.describe()
# Out:
# (1593, 2651)
#        opportunity_id  current_date_day  current_date_month  \
# count    1.593000e+03       1593.000000         1593.000000
# mean     4.375875e+18         16.441933            7.168236
# std      2.493243e+18          8.594175            3.201259
# min      1.542746e+16          1.000000            1.000000
# 25%      2.454665e+18          9.000000            5.000000
# 50%      3.809525e+18         17.000000            7.000000
# 75%      6.652569e+18         24.000000           10.000000
# max      9.207329e+18         31.000000           12.000000
#
#        current_date_year  TOPICS__mean_calls_Integration__from_opp_creation  \
# count        1593.000000                                          82.000000
# mean         2020.433773                                        1166.524741
# std             0.820307                                         353.240320
# min          2018.000000                                         380.783692
# ...

# %%
data.head()
# Out:
#       opportunity_id  current_date_day  current_date_month  current_date_year  \
# 0  15427464874523186                 2                  11               2021
# 1  15427464874523186                 9                  11               2021
# 2  53852196172413351                11                  10               2021
# 3  63848905825323247                25                   7               2021
# 4  63848905825323247                 1                   8               2021
#
#    TOPICS__mean_calls_Integration__from_opp_creation  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    TOPICS__min_calls_Library__last_28_days  \
# 0                                      NaN
# 1                                      NaN
# ...

# %% [markdown]
# Pipe line idee:
# MICE ofzo om van de nan values af tekomen:
# https://towardsdatascience.com/whats-the-best-way-to-handle-nan-values-62d50f738fc
#
# Dan iets van PCA en dimensionality reduction ofzo zodat de de minder nuttige variables eruit gaan en de dimensies behapbaarder zijn.
